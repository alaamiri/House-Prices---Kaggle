# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns 
import sweetviz as sv

# %% [markdown]
# Analyze

# %%
train_fn = "./data/train.csv"
test_fn = "./data/test.csv"

def readData(fname):
    df = pd.read_csv(fname)

    return df

train_df = readData(train_fn)
test_df = readData(test_fn)

# %%
print(train_df.describe())
train_df.info(False)
print(train_df.dtypes)
#heatmap correlation
#print(df.corr())
#sns.pairplot(df)
#sns.heatmap(df.corr(), annot=True)
#plt.show()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
col_float = train_df.select_dtypes(include='float64')
col_float.head()
col_float.describe()
# Out:
#        LotFrontage   MasVnrArea  GarageYrBlt
# count  1201.000000  1452.000000  1379.000000
# mean     70.049958   103.685262  1978.506164
# std      24.284752   181.066207    24.689725
# min      21.000000     0.000000  1900.000000
# 25%      59.000000     0.000000  1961.000000
# 50%      69.000000     0.000000  1980.000000
# 75%      80.000000   166.000000  2002.000000
# max     313.000000  1600.000000  2010.000000

# %% [markdown]
# 1460 entries, 81 features, more than half of the features are not a number type. Let us see the `object` columns.

# %%
col_int = train_df.select_dtypes(include='int64')
col_int.head()
col_int.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411  ...
# std      30.202904     20.645407   456.098091   161.319273   441.866955  ...
# ...

# %%
col_object =  train_df.select_dtypes(include='object')
col_object.head()
col_object.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
col_object.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %% [markdown]
# From the head and the describtion of the object only features dataframe, we can see for example for the feature `Alley`, that we have 2 different values, and only 91 of the entries have a non NaN value.

# %% [markdown]
# The keep the dataset coherent and efficient, we will change the 'object' features to 'category'

# %%
def object_to_category(df):
    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype('category')

object_to_category(train_df)
print(train_df.dtypes)
print(train_df.describe())
# Out:
# Id                  int64
# MSSubClass          int64
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
#                    ...
# MoSold              int64
# YrSold              int64
# SaleType         category
# SaleCondition    category
# SalePrice           int64
# Length: 81, dtype: object
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# ...

# %%
def category_to_code(df):
    for col in df.select_dtypes(include='category').columns:
        df[col] = df[col].cat.codes

category_to_code(train_df)
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1     -1         3
# 1   2          20         3         80.0     9600       1     -1         3
# 2   3          60         3         68.0    11250       1     -1         0
# 3   4          70         3         60.0     9550       1     -1         0
# 4   5          60         3         84.0    14260       1     -1         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0      -1     -1           -1        0
# 1            3          0  ...         0      -1     -1           -1        0
# 2            3          0  ...         0      -1     -1           -1        0
# 3            3          0  ...         0      -1     -1           -1        0
# 4            3          0  ...         0      -1     -1           -1        0
#
# ...

# %%
correlations = train_df.corr(method='spearman')

corr_saleprice = correlations["SalePrice"].sort_values(ascending=False)
print(corr_saleprice)

plt.figure(figsize=(12, 10))
sns.heatmap(correlations, cmap="coolwarm", annot=False, linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
# Out:
# SalePrice       1.000000
# OverallQual     0.809829
# GrLivArea       0.731310
# GarageCars      0.690711
# YearBuilt       0.652682
#                   ...
# GarageFinish   -0.381497
# HeatingQC      -0.471338
# BsmtQual       -0.479974
# KitchenQual    -0.569857
# ExterQual      -0.633315
# Name: SalePrice, Length: 81, dtype: float64

# %%
top_features = corr_saleprice[abs(corr_saleprice) > 0.4].index
sns.heatmap(train_df[top_features].corr(method='spearman'), annot=False, cmap="coolwarm")
plt.title("Spearman Correlation of features > 0.4")
plt.show()
